# %% [markdown]
# ## Celebrity Image Classifier

# %%
# Importing the required libraries
import numpy as np
import cv2
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# Reading a sample image using cv2 library
img = cv2.imread("test_images/messi.jpg")
img.shape
# Out:
# (1019, 720, 3)

# %%
plt.imshow(img)

# %%
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
gray.shape
# Out:
# (1019, 720)

# %%
# Gray scaling the image
plt.imshow(gray, cmap='gray')

# %%
face_cascade = cv2.CascadeClassifier('./opencv/haarcascades/haarcascade_frontalface_default.xml')
eye_cascade = cv2.CascadeClassifier('./opencv/haarcascades/haarcascade_eye.xml')

faces = face_cascade.detectMultiScale(gray, 1.3, 5)
faces
# Out:
# array([[142, 179, 500, 500]], dtype=int32)

# %%
(x,y,w,h) = faces[0]
x,y,w,h
# Out:
# (142, 179, 500, 500)

# %%
face_img = cv2.rectangle(img,(x,y),(x+w,y+h),(255,0,0),2)
plt.imshow(face_img)

# %%
cv2.destroyAllWindows()
for (x,y,w,h) in faces:
    face_img = cv2.rectangle(img,(x,y),(x+w,y+h),(255,0,0),2)
    roi_gray = gray[y:y+h, x:x+w]
    roi_color = face_img[y:y+h, x:x+w]
    eyes = eye_cascade.detectMultiScale(roi_gray)
    for (ex,ey,ew,eh) in eyes:
        cv2.rectangle(roi_color,(ex,ey),(ex+ew,ey+eh),(0,255,0),2)
        

plt.figure()
plt.imshow(face_img, cmap='gray')
plt.show()

# %%
plt.imshow(roi_color, cmap='gray')

# %%
cropped_img = np.array(roi_color)
cropped_img.shape
# Out:
# (500, 500, 3)

# %%
def get_cropped_image_if_2_eyes(image_path):
    img = cv2.imread(image_path)
    gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    faces = face_cascade.detectMultiScale(gray, 1.3, 5)
    for (x,y,w,h) in faces:
        roi_gray = gray[y:y+h, x:x+w]
        roi_color = img[y:y+h, x:x+w]
        eyes = eye_cascade.detectMultiScale(roi_gray)
        if len(eyes) >= 2:
            return roi_color

# %%
cropped_image = get_cropped_image_if_2_eyes('./test_images/messi.jpg')
plt.imshow(cropped_image)

# %%
org_image_obstructed = cv2.imread('./test_images/messi2.jpg')
plt.imshow(org_image_obstructed)

# %%
cropped_image_no_2_eyes = get_cropped_image_if_2_eyes('./test_images/messi2.jpg')
cropped_image_no_2_eyes

# %%
path_to_data = "./Dataset/"
path_to_cr_data = "./Dataset/Cropped/"

# %%
import os
img_dirs = []
for entry in os.scandir(path_to_data):
    if entry.is_dir():
        img_dirs.append(entry.path)

# %%
img_dirs
# Out:
# ['./Dataset/saina_nehwal',
#  './Dataset/tom_cruise',
#  './Dataset/virat_kohli',
#  './Dataset/lionel_messi',
#  './Dataset/shah_rukh']

# %%
import shutil
if os.path.exists(path_to_cr_data):
     shutil.rmtree(path_to_cr_data)
os.mkdir(path_to_cr_data)

# %%
cropped_image_dirs = []
celebrity_file_names_dict = {}
for img_dir in img_dirs:
    count = 1
    celebrity_name = img_dir.split('/')[-1]
    celebrity_file_names_dict[celebrity_name] = []
    for entry in os.scandir(img_dir):
        roi_color = get_cropped_image_if_2_eyes(entry.path)
        if roi_color is not None:
            cropped_folder = path_to_cr_data + celebrity_name
            if not os.path.exists(cropped_folder):
                os.makedirs(cropped_folder)
                cropped_image_dirs.append(cropped_folder)
                print("Generating cropped images in folder: ",cropped_folder)
            cropped_file_name = celebrity_name + str(count) + ".png"
            cropped_file_path = cropped_folder + "/" + cropped_file_name
            cv2.imwrite(cropped_file_path, roi_color)
            celebrity_file_names_dict[celebrity_name].append(cropped_file_path)
            count += 1
# Out:
# Generating cropped images in folder:  ./Dataset/Cropped/saina_nehwal
# Generating cropped images in folder:  ./Dataset/Cropped/tom_cruise
# Generating cropped images in folder:  ./Dataset/Cropped/virat_kohli
# Generating cropped images in folder:  ./Dataset/Cropped/lionel_messi
# Generating cropped images in folder:  ./Dataset/Cropped/shah_rukh

# %%
import numpy as np
import pywt
import cv2    

def w2d(img, mode='haar', level=1):
    imArray = img
    #Datatype conversions
    #convert to grayscale
    imArray = cv2.cvtColor( imArray,cv2.COLOR_RGB2GRAY )
    #convert to float
    imArray =  np.float32(imArray)   
    imArray /= 255;
    # compute coefficients 
    coeffs=pywt.wavedec2(imArray, mode, level=level)

    #Process Coefficients
    coeffs_H=list(coeffs)  
    coeffs_H[0] *= 0;  

    # reconstruction
    imArray_H=pywt.waverec2(coeffs_H, mode);
    imArray_H *= 255;
    imArray_H =  np.uint8(imArray_H)

    return imArray_H

# %%
im_har = w2d(cropped_img,'db1',5)
plt.imshow(im_har, cmap='gray')

# %%
celebrity_file_names_dict = {}
for img_dir in cropped_image_dirs:
    celebrity_name = img_dir.split('/')[-1]
    file_list = []
    for entry in os.scandir(img_dir):
        file_list.append(entry.path)
    celebrity_file_names_dict[celebrity_name] = file_list
celebrity_file_names_dict
# Out:
# {'saina_nehwal': ['./Dataset/Cropped/saina_nehwal/saina_nehwal6.png',
#   './Dataset/Cropped/saina_nehwal/saina_nehwal7.png',
#   './Dataset/Cropped/saina_nehwal/saina_nehwal5.png',
#   './Dataset/Cropped/saina_nehwal/saina_nehwal4.png',
#   './Dataset/Cropped/saina_nehwal/.DS_Store',
#   './Dataset/Cropped/saina_nehwal/saina_nehwal1.png',
#   './Dataset/Cropped/saina_nehwal/saina_nehwal3.png',
#   './Dataset/Cropped/saina_nehwal/saina_nehwal2.png',
#   './Dataset/Cropped/saina_nehwal/saina_nehwal17.png',
#   './Dataset/Cropped/saina_nehwal/saina_nehwal16.png',
#   './Dataset/Cropped/saina_nehwal/saina_nehwal14.png',
#   './Dataset/Cropped/saina_nehwal/saina_nehwal28.png',
#   './Dataset/Cropped/saina_nehwal/saina_nehwal29.png',
#   './Dataset/Cropped/saina_nehwal/saina_nehwal15.png',
#   './Dataset/Cropped/saina_nehwal/saina_nehwal11.png',
#   './Dataset/Cropped/saina_nehwal/saina_nehwal10.png',
#   './Dataset/Cropped/saina_nehwal/saina_nehwal12.png',
#   './Dataset/Cropped/saina_nehwal/saina_nehwal13.png',
#   './Dataset/Cropped/saina_nehwal/saina_nehwal22.png',
#   './Dataset/Cropped/saina_nehwal/saina_nehwal23.png',
#   './Dataset/Cropped/saina_nehwal/saina_nehwal21.png',
#   './Dataset/Cropped/saina_nehwal/saina_nehwal20.png',
#   './Dataset/Cropped/saina_nehwal/saina_nehwal18.png',
#   './Dataset/Cropped/saina_nehwal/saina_nehwal24.png',
#   './Dataset/Cropped/saina_nehwal/saina_nehwal30.png',
#   './Dataset/Cropped/saina_nehwal/saina_nehwal31.png',
#   './Dataset/Cropped/saina_nehwal/saina_nehwal25.png',
#   './Dataset/Cropped/saina_nehwal/saina_nehwal19.png',
#   './Dataset/Cropped/saina_nehwal/saina_nehwal33.png',
#   './Dataset/Cropped/saina_nehwal/saina_nehwal27.png',
#   './Dataset/Cropped/saina_nehwal/saina_nehwal26.png',
#   './Dataset/Cropped/saina_nehwal/saina_nehwal32.png',
#   './Dataset/Cropped/saina_nehwal/saina_nehwal8.png'],
#  'tom_cruise': ['./Dataset/Cropped/tom_cruise/tom_cruise2.png',
#   './Dataset/Cropped/tom_cruise/tom_cruise3.png',
#   './Dataset/Cropped/tom_cruise/tom_cruise1.png',
#   './Dataset/Cropped/tom_cruise/tom_cruise4.png',
#   './Dataset/Cropped/tom_cruise/.DS_Store',
#   './Dataset/Cropped/tom_cruise/tom_cruise5.png',
#   './Dataset/Cropped/tom_cruise/tom_cruise7.png',
#   './Dataset/Cropped/tom_cruise/tom_cruise21.png',
#   './Dataset/Cropped/tom_cruise/tom_cruise20.png',
#   './Dataset/Cropped/tom_cruise/tom_cruise22.png',
#   './Dataset/Cropped/tom_cruise/tom_cruise23.png',
#   './Dataset/Cropped/tom_cruise/tom_cruise18.png',
#   './Dataset/Cropped/tom_cruise/tom_cruise24.png',
#   './Dataset/Cropped/tom_cruise/tom_cruise19.png',
#   './Dataset/Cropped/tom_cruise/tom_cruise14.png',
#   './Dataset/Cropped/tom_cruise/tom_cruise15.png',
#   './Dataset/Cropped/tom_cruise/tom_cruise17.png',
#   './Dataset/Cropped/tom_cruise/tom_cruise16.png',
#   './Dataset/Cropped/tom_cruise/tom_cruise12.png',
#   './Dataset/Cropped/tom_cruise/tom_cruise13.png',
#   './Dataset/Cropped/tom_cruise/tom_cruise11.png',
#   './Dataset/Cropped/tom_cruise/tom_cruise10.png',
#   './Dataset/Cropped/tom_cruise/tom_cruise8.png',
#   './Dataset/Cropped/tom_cruise/tom_cruise9.png'],
#  'virat_kohli': ['./Dataset/Cropped/virat_kohli/virat_kohli1.png',
#   './Dataset/Cropped/virat_kohli/virat_kohli47.png',
#   './Dataset/Cropped/virat_kohli/virat_kohli46.png',
#   './Dataset/Cropped/virat_kohli/virat_kohli44.png',
#   './Dataset/Cropped/virat_kohli/virat_kohli45.png',
#   './Dataset/Cropped/virat_kohli/virat_kohli3.png',
#   './Dataset/Cropped/virat_kohli/virat_kohli7.png',
#   './Dataset/Cropped/virat_kohli/.DS_Store',
#   './Dataset/Cropped/virat_kohli/virat_kohli41.png',
#   './Dataset/Cropped/virat_kohli/virat_kohli40.png',
#   './Dataset/Cropped/virat_kohli/virat_kohli6.png',
#   './Dataset/Cropped/virat_kohli/virat_kohli4.png',
#   './Dataset/Cropped/virat_kohli/virat_kohli42.png',
#   './Dataset/Cropped/virat_kohli/virat_kohli43.png',
#   './Dataset/Cropped/virat_kohli/virat_kohli18.png',
#   './Dataset/Cropped/virat_kohli/virat_kohli24.png',
#   './Dataset/Cropped/virat_kohli/virat_kohli30.png',
#   './Dataset/Cropped/virat_kohli/virat_kohli25.png',
#   './Dataset/Cropped/virat_kohli/virat_kohli19.png',
#   './Dataset/Cropped/virat_kohli/virat_kohli33.png',
#   './Dataset/Cropped/virat_kohli/virat_kohli27.png',
#   './Dataset/Cropped/virat_kohli/virat_kohli26.png',
#   './Dataset/Cropped/virat_kohli/virat_kohli32.png',
#   './Dataset/Cropped/virat_kohli/virat_kohli22.png',
#   './Dataset/Cropped/virat_kohli/virat_kohli23.png',
#   './Dataset/Cropped/virat_kohli/virat_kohli37.png',
#   './Dataset/Cropped/virat_kohli/virat_kohli21.png',
#   './Dataset/Cropped/virat_kohli/virat_kohli35.png',
#   './Dataset/Cropped/virat_kohli/virat_kohli34.png',
#   './Dataset/Cropped/virat_kohli/virat_kohli20.png',
#   './Dataset/Cropped/virat_kohli/virat_kohli39.png',
#   './Dataset/Cropped/virat_kohli/virat_kohli11.png',
#   './Dataset/Cropped/virat_kohli/virat_kohli10.png',
#   './Dataset/Cropped/virat_kohli/virat_kohli12.png',
#   './Dataset/Cropped/virat_kohli/virat_kohli17.png',
#   './Dataset/Cropped/virat_kohli/virat_kohli16.png',
#   './Dataset/Cropped/virat_kohli/virat_kohli14.png',
#   './Dataset/Cropped/virat_kohli/virat_kohli28.png',
#   './Dataset/Cropped/virat_kohli/virat_kohli15.png',
#   './Dataset/Cropped/virat_kohli/virat_kohli9.png',
#   './Dataset/Cropped/virat_kohli/virat_kohli48.png'],
#  'lionel_messi': ['./Dataset/Cropped/lionel_messi/.DS_Store',
#   './Dataset/Cropped/lionel_messi/lionel_messi9.png',
#   './Dataset/Cropped/lionel_messi/lionel_messi39.png',
#   './Dataset/Cropped/lionel_messi/lionel_messi10.png',
#   './Dataset/Cropped/lionel_messi/lionel_messi38.png',
#   './Dataset/Cropped/lionel_messi/lionel_messi8.png',
#   './Dataset/Cropped/lionel_messi/lionel_messi12.png',
#   './Dataset/Cropped/lionel_messi/lionel_messi13.png',
#   './Dataset/Cropped/lionel_messi/lionel_messi17.png',
#   './Dataset/Cropped/lionel_messi/lionel_messi28.png',
#   './Dataset/Cropped/lionel_messi/lionel_messi29.png',
#   './Dataset/Cropped/lionel_messi/lionel_messi15.png',
#   './Dataset/Cropped/lionel_messi/lionel_messi18.png',
#   './Dataset/Cropped/lionel_messi/lionel_messi30.png',
#   './Dataset/Cropped/lionel_messi/lionel_messi24.png',
#   './Dataset/Cropped/lionel_messi/lionel_messi25.png',
#   './Dataset/Cropped/lionel_messi/lionel_messi31.png',
#   './Dataset/Cropped/lionel_messi/lionel_messi19.png',
#   './Dataset/Cropped/lionel_messi/lionel_messi1.png',
#   './Dataset/Cropped/lionel_messi/lionel_messi3.png',
#   './Dataset/Cropped/lionel_messi/lionel_messi27.png',
#   './Dataset/Cropped/lionel_messi/lionel_messi33.png',
#   './Dataset/Cropped/lionel_messi/lionel_messi32.png',
#   './Dataset/Cropped/lionel_messi/lionel_messi26.png',
#   './Dataset/Cropped/lionel_messi/lionel_messi2.png',
#   './Dataset/Cropped/lionel_messi/lionel_messi6.png',
#   './Dataset/Cropped/lionel_messi/lionel_messi22.png',
#   './Dataset/Cropped/lionel_messi/lionel_messi36.png',
#   './Dataset/Cropped/lionel_messi/lionel_messi37.png',
#   './Dataset/Cropped/lionel_messi/lionel_messi23.png',
#   './Dataset/Cropped/lionel_messi/lionel_messi7.png',
#   './Dataset/Cropped/lionel_messi/lionel_messi5.png',
#   './Dataset/Cropped/lionel_messi/lionel_messi35.png',
#   './Dataset/Cropped/lionel_messi/lionel_messi21.png',
#   './Dataset/Cropped/lionel_messi/lionel_messi20.png',
#   './Dataset/Cropped/lionel_messi/lionel_messi34.png',
#   './Dataset/Cropped/lionel_messi/lionel_messi4.png'],
#  'shah_rukh': ['./Dataset/Cropped/shah_rukh/.DS_Store',
#   './Dataset/Cropped/shah_rukh/shah_rukh16.png',
#   './Dataset/Cropped/shah_rukh/shah_rukh1.png',
#   './Dataset/Cropped/shah_rukh/shah_rukh17.png',
#   './Dataset/Cropped/shah_rukh/shah_rukh15.png',
#   './Dataset/Cropped/shah_rukh/shah_rukh29.png',
#   './Dataset/Cropped/shah_rukh/shah_rukh3.png',
#   './Dataset/Cropped/shah_rukh/shah_rukh2.png',
#   './Dataset/Cropped/shah_rukh/shah_rukh28.png',
#   './Dataset/Cropped/shah_rukh/shah_rukh14.png',
#   './Dataset/Cropped/shah_rukh/shah_rukh6.png',
#   './Dataset/Cropped/shah_rukh/shah_rukh10.png',
#   './Dataset/Cropped/shah_rukh/shah_rukh11.png',
#   './Dataset/Cropped/shah_rukh/shah_rukh7.png',
#   './Dataset/Cropped/shah_rukh/shah_rukh5.png',
#   './Dataset/Cropped/shah_rukh/shah_rukh13.png',
#   './Dataset/Cropped/shah_rukh/shah_rukh12.png',
#   './Dataset/Cropped/shah_rukh/shah_rukh4.png',
#   './Dataset/Cropped/shah_rukh/shah_rukh23.png',
#   './Dataset/Cropped/shah_rukh/shah_rukh9.png',
#   './Dataset/Cropped/shah_rukh/shah_rukh37.png',
#   './Dataset/Cropped/shah_rukh/shah_rukh8.png',
#   './Dataset/Cropped/shah_rukh/shah_rukh36.png',
#   './Dataset/Cropped/shah_rukh/shah_rukh22.png',
#   './Dataset/Cropped/shah_rukh/shah_rukh34.png',
#   './Dataset/Cropped/shah_rukh/shah_rukh20.png',
#   './Dataset/Cropped/shah_rukh/shah_rukh21.png',
#   './Dataset/Cropped/shah_rukh/shah_rukh35.png',
#   './Dataset/Cropped/shah_rukh/shah_rukh19.png',
#   './Dataset/Cropped/shah_rukh/shah_rukh31.png',
#   './Dataset/Cropped/shah_rukh/shah_rukh24.png',
#   './Dataset/Cropped/shah_rukh/shah_rukh30.png',
#   './Dataset/Cropped/shah_rukh/shah_rukh18.png',
#   './Dataset/Cropped/shah_rukh/shah_rukh26.png',
#   './Dataset/Cropped/shah_rukh/shah_rukh32.png',
#   './Dataset/Cropped/shah_rukh/shah_rukh33.png',
#   './Dataset/Cropped/shah_rukh/shah_rukh27.png']}

# %%
class_dict = {}
count = 0
for celebrity_name in celebrity_file_names_dict.keys():
    class_dict[celebrity_name] = count
    count = count + 1
class_dict
# Out:
# {'saina_nehwal': 0,
#  'tom_cruise': 1,
#  'virat_kohli': 2,
#  'lionel_messi': 3,
#  'shah_rukh': 4}

# %%
X, y = [], []
for celebrity_name, training_files in celebrity_file_names_dict.items():
    for training_image in training_files:
        img = cv2.imread(training_image)
        if img is None:
            continue
        scalled_raw_img = cv2.resize(img, (32, 32))
        img_har = w2d(img,'db1',5)
        scalled_img_har = cv2.resize(img_har, (32, 32))
        combined_img = np.vstack((scalled_raw_img.reshape(32*32*3,1),scalled_img_har.reshape(32*32,1)))
        X.append(combined_img)
        y.append(class_dict[celebrity_name])

# %%
len(X)
# Out:
# 167

# %%
len(X[0])
# Out:
# 4096

# %%
X = np.array(X).reshape(len(X),4096).astype(float)
X.shape
# Out:
# (167, 4096)

# %%
from sklearn.svm import SVC
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.pipeline import Pipeline
from sklearn.metrics import classification_report

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=0)

# %%
pipe = Pipeline([('scaler', StandardScaler()), ('svc', SVC(kernel = 'rbf', C = 10))])
pipe.fit(X_train, y_train)
pipe.score(X_test, y_test)
# Out:
# 0.8571428571428571

# %%
print(classification_report(y_test, pipe.predict(X_test)))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.60      1.00      0.75         6
#            1       1.00      0.50      0.67         6
#            2       0.83      1.00      0.91        10
#            3       1.00      0.90      0.95        10
#            4       1.00      0.80      0.89        10
#
#     accuracy                           0.86        42
#    macro avg       0.89      0.84      0.83        42
# weighted avg       0.90      0.86      0.86        42

# %%
from sklearn import svm
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.pipeline import make_pipeline
from sklearn.model_selection import GridSearchCV

# %%
model_params = {
    'svm': {
        'model': svm.SVC(gamma='auto',probability=True),
        'params' : {
            'svc__C': [1,10,100,1000],
            'svc__kernel': ['rbf','linear']
        }  
    },
    'random_forest': {
        'model': RandomForestClassifier(),
        'params' : {
            'randomforestclassifier__n_estimators': [1,5,10]
        }
    },
    'logistic_regression' : {
        'model': LogisticRegression(solver='liblinear',multi_class='auto'),
        'params': {
            'logisticregression__C': [1,5,10]
        }
    }
}

# %%
scores = []
best_estimators = {}
import pandas as pd
for algo, mp in model_params.items():
    pipe = make_pipeline(StandardScaler(), mp['model'])
    clf =  GridSearchCV(pipe, mp['params'], cv=5, return_train_score=False)
    clf.fit(X_train, y_train)
    scores.append({
        'model': algo,
        'best_score': clf.best_score_,
        'best_params': clf.best_params_
    })
    best_estimators[algo] = clf.best_estimator_
    
df = pd.DataFrame(scores,columns=['model','best_score','best_params'])
df
# Out:
#                  model  best_score  \
# 0                  svm    0.688889
# 1        random_forest    0.577778
# 2  logistic_regression    0.711111
#
#                                     best_params
# 0          {'svc__C': 10, 'svc__kernel': 'rbf'}
# 1  {'randomforestclassifier__n_estimators': 10}
# 2                  {'logisticregression__C': 1}

# %%
best_estimators
# Out:
# {'svm': Pipeline(steps=[('standardscaler', StandardScaler()),
#                  ('svc', SVC(C=10, gamma='auto', probability=True))]),
#  'random_forest': Pipeline(steps=[('standardscaler', StandardScaler()),
#                  ('randomforestclassifier',
#                   RandomForestClassifier(n_estimators=10))]),
#  'logistic_regression': Pipeline(steps=[('standardscaler', StandardScaler()),
#                  ('logisticregression',
#                   LogisticRegression(C=1, solver='liblinear'))])}

# %%
best_estimators['svm'].score(X_test,y_test)
# Out:
# 0.9523809523809523

# %%
best_estimators['random_forest'].score(X_test,y_test)
# Out:
# 0.8809523809523809

# %%
best_estimators['logistic_regression'].score(X_test,y_test)
# Out:
# 0.9761904761904762

# %%
best_clf = best_estimators['svm']

# %%
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test, best_clf.predict(X_test))
cm
# Out:
# array([[ 6,  0,  0,  0,  0],
#        [ 0,  5,  0,  0,  1],
#        [ 0,  0, 10,  0,  0],
#        [ 0,  0,  0, 10,  0],
#        [ 0,  0,  1,  0,  9]])

# %%
import seaborn as sn
plt.figure(figsize = (10,7))
sn.heatmap(cm, annot=True)
plt.xlabel('Predicted')
plt.ylabel('Truth')
# Out:
# Text(95.72222222222221, 0.5, 'Truth')

# %%
class_dict
# Out:
# {'saina_nehwal': 0,
#  'tom_cruise': 1,
#  'virat_kohli': 2,
#  'lionel_messi': 3,
#  'shah_rukh': 4}

# %%
import joblib 
# Save the model as a pickle in a file 
joblib.dump(best_clf, 'saved_model.pkl')
# Out:
# ['saved_model.pkl']

# %%
import json
with open("class_dictionary.json","w") as f:
    f.write(json.dumps(class_dict))
